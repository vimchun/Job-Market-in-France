# %%
import os

import pandas as pd

# %% [markdown]
# # <u> Fichiers du lien_2 </u>

# %%
files_directory = os.path.join("..", "additional_files", "archives", "lien_2")
file_commune = "v_commune_2024.csv"
file_departement = "v_departement_2024.csv"
file_region = "v_region_2024.csv"

# %% [markdown]
# ## <u> df_commune </u>

# %%
df_commune = pd.read_csv(
    os.path.join(files_directory, file_commune),
    usecols=[
        "COM",
        "REG",
        "DEP",
        "LIBELLE",
    ],
)

# %%
df_commune
# Out:
#          COM   REG  DEP                  LIBELLE
# 0      01001  84.0   01  L'Abergement-Clémenciat
# 1      01002  84.0   01    L'Abergement-de-Varey
# 2      01004  84.0   01        Ambérieu-en-Bugey
# 3      01005  84.0   01      Ambérieux-en-Dombes
# 4      01006  84.0   01                  Ambléon
# ...      ...   ...  ...                      ...
# 37539  97613   6.0  976            M'Tsangamouji
# 37540  97614   6.0  976                 Ouangani
# 37541  97615   6.0  976                 Pamandzi
# 37542  97616   6.0  976                     Sada
# 37543  97617   6.0  976                 Tsingoni
#
# [37544 rows x 4 columns]

# %%
df_commune.rename(
    {
        "COM": "code_insee",
        "REG": "code_region",
        "DEP": "code_departement",
        "LIBELLE": "nom_commune",
    },
    axis=1,
    inplace=True,
)

# %%
# On ajoute une colonne nom_ville (idem que nom_commune sans les arrondissements pour Paris, Marseille et Lyon)
#  car on va préférer "Lyon" à "Lyon 1er Arrondissement" ou "Lyon 2e Arrondissement"...

df_commune["nom_ville"] = df_commune.apply(lambda x: x.nom_commune.split(" ")[0] if "Arrondissement" in x.nom_commune else x.nom_commune, axis=1)

# %%
# Vérification
df_commune[df_commune.nom_commune.str.contains("Arrondissement")]
# Out:
#       code_insee  code_region code_departement                   nom_commune  \
# 4598       13201         93.0               13  Marseille 1er Arrondissement
# 4599       13202         93.0               13   Marseille 2e Arrondissement
# 4600       13203         93.0               13   Marseille 3e Arrondissement
# 4601       13204         93.0               13   Marseille 4e Arrondissement
# 4602       13205         93.0               13   Marseille 5e Arrondissement
# 4603       13206         93.0               13   Marseille 6e Arrondissement
# 4604       13207         93.0               13   Marseille 7e Arrondissement
# 4605       13208         93.0               13   Marseille 8e Arrondissement
# 4606       13209         93.0               13   Marseille 9e Arrondissement
# 4607       13210         93.0               13  Marseille 10e Arrondissement
# 4608       13211         93.0               13  Marseille 11e Arrondissement
# 4609       13212         93.0               13  Marseille 12e Arrondissement
# 4610       13213         93.0               13  Marseille 13e Arrondissement
# 4611       13214         93.0               13  Marseille 14e Arrondissement
# 4612       13215         93.0               13  Marseille 15e Arrondissement
# 4613       13216         93.0               13  Marseille 16e Arrondissement
# 29324      69381         84.0               69       Lyon 1er Arrondissement
# 29325      69382         84.0               69        Lyon 2e Arrondissement
# 29326      69383         84.0               69        Lyon 3e Arrondissement
# 29327      69384         84.0               69        Lyon 4e Arrondissement
# 29328      69385         84.0               69        Lyon 5e Arrondissement
# 29329      69386         84.0               69        Lyon 6e Arrondissement
# 29330      69387         84.0               69        Lyon 7e Arrondissement
# 29331      69388         84.0               69        Lyon 8e Arrondissement
# 29332      69389         84.0               69        Lyon 9e Arrondissement
# 31483      75101         11.0               75      Paris 1er Arrondissement
# 31484      75102         11.0               75       Paris 2e Arrondissement
# 31485      75103         11.0               75       Paris 3e Arrondissement
# 31486      75104         11.0               75       Paris 4e Arrondissement
# 31487      75105         11.0               75       Paris 5e Arrondissement
# 31488      75106         11.0               75       Paris 6e Arrondissement
# 31489      75107         11.0               75       Paris 7e Arrondissement
# 31490      75108         11.0               75       Paris 8e Arrondissement
# 31491      75109         11.0               75       Paris 9e Arrondissement
# 31492      75110         11.0               75      Paris 10e Arrondissement
# 31493      75111         11.0               75      Paris 11e Arrondissement
# 31494      75112         11.0               75      Paris 12e Arrondissement
# 31495      75113         11.0               75      Paris 13e Arrondissement
# 31496      75114         11.0               75      Paris 14e Arrondissement
# 31497      75115         11.0               75      Paris 15e Arrondissement
# 31498      75116         11.0               75      Paris 16e Arrondissement
# 31499      75117         11.0               75      Paris 17e Arrondissement
# 31500      75118         11.0               75      Paris 18e Arrondissement
# 31501      75119         11.0               75      Paris 19e Arrondissement
# 31502      75120         11.0               75      Paris 20e Arrondissement
#
#        nom_ville
# 4598   Marseille
# 4599   Marseille
# 4600   Marseille
# 4601   Marseille
# 4602   Marseille
# 4603   Marseille
# 4604   Marseille
# 4605   Marseille
# 4606   Marseille
# 4607   Marseille
# 4608   Marseille
# 4609   Marseille
# 4610   Marseille
# 4611   Marseille
# 4612   Marseille
# 4613   Marseille
# 29324       Lyon
# 29325       Lyon
# 29326       Lyon
# 29327       Lyon
# 29328       Lyon
# 29329       Lyon
# 29330       Lyon
# 29331       Lyon
# 29332       Lyon
# 31483      Paris
# 31484      Paris
# 31485      Paris
# 31486      Paris
# 31487      Paris
# 31488      Paris
# 31489      Paris
# 31490      Paris
# 31491      Paris
# 31492      Paris
# 31493      Paris
# 31494      Paris
# 31495      Paris
# 31496      Paris
# 31497      Paris
# 31498      Paris
# 31499      Paris
# 31500      Paris
# 31501      Paris
# 31502      Paris

# %%
df_commune
# Out:
#       code_insee  code_region code_departement              nom_commune  \
# 0          01001         84.0               01  L'Abergement-Clémenciat
# 1          01002         84.0               01    L'Abergement-de-Varey
# 2          01004         84.0               01        Ambérieu-en-Bugey
# 3          01005         84.0               01      Ambérieux-en-Dombes
# 4          01006         84.0               01                  Ambléon
# ...          ...          ...              ...                      ...
# 37539      97613          6.0              976            M'Tsangamouji
# 37540      97614          6.0              976                 Ouangani
# 37541      97615          6.0              976                 Pamandzi
# 37542      97616          6.0              976                     Sada
# 37543      97617          6.0              976                 Tsingoni
#
#                      nom_ville
# 0      L'Abergement-Clémenciat
# 1        L'Abergement-de-Varey
# 2            Ambérieu-en-Bugey
# 3          Ambérieux-en-Dombes
# 4                      Ambléon
# ...                        ...
# 37539            M'Tsangamouji
# 37540                 Ouangani
# 37541                 Pamandzi
# 37542                     Sada
# 37543                 Tsingoni
#
# [37544 rows x 5 columns]

# %% [markdown]
# ## <u> df_departement </u>

# %%
df_departement = pd.read_csv(
    os.path.join(files_directory, file_departement),
    usecols=[
        "DEP",
        "LIBELLE",
    ],
)

# %%
df_departement.rename(
    {
        "DEP": "code_departement",
        "LIBELLE": "nom_departement",
    },
    axis=1,
    inplace=True,
)

# %%
df_departement
# Out:
#     code_departement          nom_departement
# 0                 01                      Ain
# 1                 02                    Aisne
# 2                 03                   Allier
# 3                 04  Alpes-de-Haute-Provence
# 4                 05             Hautes-Alpes
# ..               ...                      ...
# 96               971               Guadeloupe
# 97               972               Martinique
# 98               973                   Guyane
# 99               974               La Réunion
# 100              976                  Mayotte
#
# [101 rows x 2 columns]

# %% [markdown]
# ## <u> df_region </u>

# %%
df_region = pd.read_csv(
    os.path.join(files_directory, file_region),
    usecols=[
        "REG",
        "LIBELLE",
    ],
)

# %%
df_region.rename(
    {
        "REG": "code_region",
        "LIBELLE": "nom_region",
    },
    axis=1,
    inplace=True,
)

# %%
df_region
# Out:
#     code_region                  nom_region
# 0             1                  Guadeloupe
# 1             2                  Martinique
# 2             3                      Guyane
# 3             4                  La Réunion
# 4             6                     Mayotte
# 5            11               Île-de-France
# 6            24         Centre-Val de Loire
# 7            27     Bourgogne-Franche-Comté
# 8            28                   Normandie
# 9            32             Hauts-de-France
# 10           44                   Grand Est
# 11           52            Pays de la Loire
# 12           53                    Bretagne
# 13           75          Nouvelle-Aquitaine
# 14           76                   Occitanie
# 15           84        Auvergne-Rhône-Alpes
# 16           93  Provence-Alpes-Côte d'Azur
# 17           94                       Corse

# %% [markdown]
# ## <u> merging </u>

# %%
df_commune.head(2)
# Out:
#   code_insee  code_region code_departement              nom_commune  \
# 0      01001         84.0               01  L'Abergement-Clémenciat
# 1      01002         84.0               01    L'Abergement-de-Varey
#
#                  nom_ville
# 0  L'Abergement-Clémenciat
# 1    L'Abergement-de-Varey

# %%
df_departement.head(2)
# Out:
#   code_departement nom_departement
# 0               01             Ain
# 1               02           Aisne

# %%
df_region.head(2)
# Out:
#    code_region  nom_region
# 0            1  Guadeloupe
# 1            2  Martinique

# %%
df_lien_2 = df_commune.merge(df_departement, on="code_departement").merge(df_region, on="code_region")

# %%
df_lien_2 = df_lien_2[["code_insee", "nom_commune", "nom_ville", "nom_departement", "nom_region"]]

# %% [markdown]
# ------------

# %% [markdown]
# # <u> Fichier du lien_3 </u>

# %% [markdown]
# ## <u> Mapping code insee <> code postal </u>

# %%
df_lien_3 = pd.read_csv(
    os.path.join("..", "additional_files", "archives", "lien_3", "cities.csv"),
    usecols=["insee_code", "zip_code"],
)

# %%
df_lien_3.rename(
    {
        "insee_code": "code_insee",
        "zip_code": "code_postal",
    },
    axis=1,
    inplace=True,
)

# %%
df_lien_3
# Out:
#       code_insee  code_postal
# 0          25620        25650
# 1          25624        25640
# 2          25615        25310
# 3          25619        25240
# 4          25622        25170
# ...          ...          ...
# 39140      98829        98829
# 39141      98831        98833
# 39142      98832        98834
# 39143      98612        98620
# 39144      98613        98600
#
# [39145 rows x 2 columns]

# %%
df_lien_3.dtypes
# Out:
# code_insee     object
# code_postal     int64
# dtype: object

# %%
# df_lien_3.astype({"code_postal": "str"})
df_lien_3["code_postal"] = df_lien_3["code_postal"].astype(str)

# %% [markdown]
# # <u> Merge des df des liens 2 et 3 </u>

# %%
df_lien_2.head(2)
# Out:
#   code_insee              nom_commune                nom_ville  \
# 0      01001  L'Abergement-Clémenciat  L'Abergement-Clémenciat
# 1      01002    L'Abergement-de-Varey    L'Abergement-de-Varey
#
#   nom_departement            nom_region
# 0             Ain  Auvergne-Rhône-Alpes
# 1             Ain  Auvergne-Rhône-Alpes

# %%
df_lien_3.head(2)
# Out:
#   code_insee code_postal
# 0      25620       25650
# 1      25624       25640

# %%
display(df_lien_2.dtypes, df_lien_3.dtypes)
# Out:
# code_insee         object
# nom_commune        object
# nom_ville          object
# nom_departement    object
# nom_region         object
# dtype: object
# code_insee     object
# code_postal    object
# dtype: object

# %%
df = pd.merge(left=df_lien_2, right=df_lien_3, on="code_insee")

# %%
df.columns
# Out:
# Index(['code_insee', 'nom_commune', 'nom_ville', 'nom_departement',
#        'nom_region', 'code_postal'],
#       dtype='object')

# %%
df = df[["code_insee", "code_postal", "nom_commune", "nom_ville", "nom_departement", "nom_region"]]

# %%
df["code_postal"] = df["code_postal"].str.zfill(5)

# %%
df
# Out:
#       code_insee code_postal              nom_commune  \
# 0          01001       01400  L'Abergement-Clémenciat
# 1          01002       01640    L'Abergement-de-Varey
# 2          01004       01500        Ambérieu-en-Bugey
# 3          01005       01330      Ambérieux-en-Dombes
# 4          01006       01300                  Ambléon
# ...          ...         ...                      ...
# 38895      97614       97670                 Ouangani
# 38896      97615       97615                 Pamandzi
# 38897      97616       97640                     Sada
# 38898      97617       97680                 Tsingoni
# 38899      97617       97680                 Tsingoni
#
#                      nom_ville nom_departement            nom_region
# 0      L'Abergement-Clémenciat             Ain  Auvergne-Rhône-Alpes
# 1        L'Abergement-de-Varey             Ain  Auvergne-Rhône-Alpes
# 2            Ambérieu-en-Bugey             Ain  Auvergne-Rhône-Alpes
# 3          Ambérieux-en-Dombes             Ain  Auvergne-Rhône-Alpes
# 4                      Ambléon             Ain  Auvergne-Rhône-Alpes
# ...                        ...             ...                   ...
# 38895                 Ouangani         Mayotte               Mayotte
# 38896                 Pamandzi         Mayotte               Mayotte
# 38897                     Sada         Mayotte               Mayotte
# 38898                 Tsingoni         Mayotte               Mayotte
# 38899                 Tsingoni         Mayotte               Mayotte
#
# [38900 rows x 6 columns]

# %%
df.dtypes
# Out:
# code_insee         object
# code_postal        object
# nom_commune        object
# nom_ville          object
# nom_departement    object
# nom_region         object
# dtype: object

# %%
display(
    df_lien_2.isna().sum().sum(),
    df_lien_3.isna().sum().sum(),
    df.isna().sum().sum(),
)
# Out:
# 0
# 0
# 0

# %% [markdown]
# # <u> Ecriture dans un fichier .csv </u>

# %%
df.to_csv(
    os.path.join("..", "additional_files", "codes__city_department_region.csv"),
    index=False,  # pour ne pas écrire les index
)
