# %%
import os

import pandas as pd

json_files_directory = os.path.join("outputs", "offres")
json_name = "_offres_concatenated_13639_offres__2025-03-05--22h09.json"

# %%
pd.options.display.max_rows = 3000
pd.options.display.max_columns = 100

# %%
df = pd.read_json(
    os.path.join(json_files_directory, json_name),
    dtype=False,
)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[152], line 1
# ----> 1 df = pd.read_json(
#       2     os.path.join(json_files_directory, json_name),
#       3     dtype=False,
#       4 )
#
# File d:\_portfolio\Job_Market\.venv\Lib\site-packages\pandas\io\json\_json.py:791, in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     788 if convert_axes is None and orient != "table":
#     789     convert_axes = True
# --> 791 json_reader = JsonReader(
#     792     path_or_buf,
#     793     orient=orient,
#     794     typ=typ,
#     795     dtype=dtype,
#     796     convert_axes=convert_axes,
#     797     convert_dates=convert_dates,
#     798     keep_default_dates=keep_default_dates,
# ...

# %%
df.head(2)
# Out:
#         id                                           intitule  \
# 0  188VMCV           Administrateur d'exploitation IBMi (H/F)
# 1  188TYYN  Technicien Sécurité Informatique Débutant H/F ...
#
#                                          description  \
# 0  Rejoignez un leader de la transformation digit...
# 1  Intégré(e) à notre équipe dédiée à la sécurité...
#
#                dateCreation         dateActualisation  \
# 0  2025-02-28T11:00:58.629Z  2025-02-28T13:21:40.016Z
# 1  2025-02-27T17:24:39.560Z  2025-02-27T17:24:40.015Z
#
#                                          lieuTravail romeCode  \
# 0  {'libelle': '38 - SEYSSINET PARISET', 'latitud...    M1817
# 1  {'libelle': '76 - Eslettes', 'latitude': 49.54...    M1817
#
#                                          romeLibelle  \
# 0  Administrateur / Administratrice sécurité info...
# 1  Administrateur / Administratrice sécurité info...
#
#                                   appellationlibelle  \
# ...

# %%
df.shape
# Out:
# (13419, 41)

# %%
lieuTravail_normalized = pd.json_normalize(df["lieuTravail"])

df = df.join(lieuTravail_normalized)

df_lieu = df[["id", "intitule"] + list(lieuTravail_normalized.columns)]

# %%
df_lieu
# Out:
#             id                                           intitule  \
# 0      188VMCV           Administrateur d'exploitation IBMi (H/F)
# 1      188TYYN  Technicien Sécurité Informatique Débutant H/F ...
# 2      188TSBV  Technicien administrateur des systèmes d'infor...
# 3      188LMFH  Administrateur systèmes, réseaux et sécurité (...
# 4      188JCHD  Adjoint du Chef de Service Informatique et Mul...
# ...        ...                                                ...
# 13414  1988889  Consultante / Consultant CRM Siebel - Montpell...
# 13415  1988437                        Ingénieur d'application H/F
# 13416  1987551                    Lead Control Engineer F/H (H/F)
# 13417  1986825                           Responsable Etudes (H/F)
# 13418  1986485                    CDI- ASSISTANT COORDINATEUR H/F
#
#                       libelle   latitude  longitude codePostal commune
# 0      38 - SEYSSINET PARISET  45.174023   5.679611      38170   38485
# ...

# %% [markdown]
# #### <u> Cas 01 : quand libelle = ("FRANCE"|"France"|"France entière") (dans ce cas code postal = code commune = NAN), et latitude = longitude = NAN </u>

# %%
# df_lieu[~df_lieu.libelle.str.match(r"^\d{2}\s-\s")].value_counts("libelle")

# %%
case_01 = df_lieu[df_lieu.libelle.isin(["FRANCE", "France", "France entière"]) \
                & df_lieu.latitude.isna() \
                & df_lieu.longitude.isna() \
                ]  # fmt:off

# %%
case_01
# Out:
#             id                                           intitule  \
# 242    1114221  Administrateur / Administratrice système et ré...
# 257    9616849                         Administrateur Système H/F
# 508    2758599      Administrateur Système et Réseau Confirmé H/F
# 566    2537811                                        Serveur H/F
# 643    2219995  Administrateur Réseaux Informatique Industriel...
# 715    1851164          Administrateur systèmes et réseau F/H H/F
# 728    1771871                                      Serveur - H/F
# 737    1746155             Administrateur systèmes et réseaux H/F
# 814    9596120                                        SERVEUR H/F
# 910    188QGQH              Technicien système informatique (H/F)
# 915    188PXQT                      Technicien informatique (H/F)
# 987    188JPTZ                      Technicien informatique (H/F)
# 1665   2837841                          Expert sécurité f/h (H/F)
# ...

# %%
# On écrit le numéro du cas dans "lieu_cas"
df_lieu.loc[df_lieu.id.isin(case_01.id), "lieu_cas"] = "cas_01"

# %%
df_lieu[df_lieu.lieu_cas != "cas_01"]
# Out:
#             id                                           intitule  \
# 0      188VMCV           Administrateur d'exploitation IBMi (H/F)
# 1      188TYYN  Technicien Sécurité Informatique Débutant H/F ...
# 2      188TSBV  Technicien administrateur des systèmes d'infor...
# 3      188LMFH  Administrateur systèmes, réseaux et sécurité (...
# 4      188JCHD  Adjoint du Chef de Service Informatique et Mul...
# ...        ...                                                ...
# 13414  1988889  Consultante / Consultant CRM Siebel - Montpell...
# 13415  1988437                        Ingénieur d'application H/F
# 13416  1987551                    Lead Control Engineer F/H (H/F)
# 13417  1986825                           Responsable Etudes (H/F)
# 13418  1986485                    CDI- ASSISTANT COORDINATEUR H/F
#
#                       libelle   latitude  longitude codePostal commune  \
# 0      38 - SEYSSINET PARISET  45.174023   5.679611      38170   38485
# ...

# %%
df_lieu.value_counts("lieu_cas")
# Out:
# lieu_cas
# cas_01    252
# Name: count, dtype: int64

# %% [markdown]
# ## <u> Cas 02 : quand libelle = ("FRANCE"|"France"|"France entière") (dans ce cas code postal = code commune = NAN), et latitude/longitude sont renseignés </u>

# %%
df_lieu[df_lieu.libelle.isin(["FRANCE", "France", "France entière"]) \
              & ~ df_lieu.latitude.isna() \
              & ~ df_lieu.longitude.isna() \
              ]  # fmt:off
# Out:
#             id                                           intitule libelle  \
# 397    2989000                 Administrateur Système Réseaux H/F  France
# 584    2494698                Administrateur Bases de Données H/F  France
# 633    2300531             Administrateur Systèmes et Réseaux H/F  France
# 654    2193109                 Administrateur Base de Données H/F  France
# 722    1787748                         Administrateur Réseaux H/F  France
# 1258   2989059                  Ingénieur Systèmes et Réseaux H/F  France
# 1410   2942555                        Technicien Informatique H/F  France
# 2198   2621785                 Technicien Systèmes et Réseaux H/F  France
# 2204   2620476                                  Chef d'Equipe H/F  France
# 2681   2347948                                 Ingénieur Data H/F  France
# 2754   2300997                      Ingénieur Système Windows H/F  France
# 2755   2300948                Ingénieur Sécurité Informatique H/F  France
# ...
