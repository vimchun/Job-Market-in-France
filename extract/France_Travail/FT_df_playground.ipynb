# %%
import os

import pandas as pd

from functions import merged_json_file_to_pd_dataframe

merged_json_filename_path = os.path.join("outputs", "offres", "_offres_merged.json")
df = merged_json_file_to_pd_dataframe(merged_json_filename_path)

df.head(2)
# Out:
#         id                                           intitule  \
# 0  186LVGH  Administrateur / Administratrice de bases de d...
# 1  186LPQN  Administrateur / Administratrice de bases de d...
#
#                                          description  \
# 0  Description du poste\nPME spécialisée dans le ...
# 1  La société VIBTIC est une société de conseil e...
#
#                dateCreation         dateActualisation  \
# 0  2025-01-10T14:17:56.871Z  2025-01-10T14:57:41.841Z
# 1  2025-01-10T12:08:26.332Z  2025-01-10T12:08:26.921Z
#
#                                          lieuTravail romeCode  \
# 0  {'libelle': '38 - ECHIROLLES', 'latitude': 45....    M1801
# 1  {'libelle': '94 - BOISSY ST LEGER', 'latitude'...    M1801
#
#                                          romeLibelle  \
# 0  Administrateur / Administratrice de systèmes d...
# 1  Administrateur / Administratrice de systèmes d...
#
#                                   appellationlibelle  \
# ...

# %%
pd.options.display.max_columns = df.shape[0]  # pour pouvoir afficher toutes les colonnes du df

# %%
df["dateCreation"] = pd.to_datetime(df["dateCreation"], format="%Y-%m-%dT%H:%M:%S.%fZ")
df["dateActualisation"] = pd.to_datetime(df["dateActualisation"], format="%Y-%m-%dT%H:%M:%S.%fZ")

# %%
df
# Out:
#             id                                           intitule  \
# 0      186LVGH  Administrateur / Administratrice de bases de d...
# 1      186LPQN  Administrateur / Administratrice de bases de d...
# 2      186KWTQ              Chargé de traitement de données (H/F)
# 3      186HMPC                                      DBA SQL (H/F)
# 4      186FRZY                                          DBA (H/F)
# ...        ...                                                ...
# 75323  9700304                  PMO / Chef de projets - F/H (H/F)
# 75327  9699899          Programmeur / Programmeuse d'études (H/F)
# 75330  9699060                           Tech Lead Frontend (H/F)
# 75331  9698971                                Ingénieur CAO (H/F)
# 75334  9698879                    Développeur Front-End React H/F
#
#                                              description  \
# 0      Description du poste\nPME spécialisée dans le ...
# ...

# %%
df.sort_values(by=["dateCreation", "dateActualisation"], ascending=True)
# Out:
#            id                                           intitule  \
# 2003  9412037                          chef bassin H/F - EC21811
# 9259  9655300                           Architecte système (H/F)
# 5474  9656120                               Chef de projet (H/F)
# 5473  9662286                     Chef de projet technique (H/F)
# 5472  9807117                              Project manager (H/F)
# ...       ...                                                ...
# 1578  0644646                           Coach en addiction (H/F)
# 6391  0644696                        Ingénieur Microsoft 365 H/F
# 2095  0644763  DECATHLON Retail Omnichannel - Vendeur / Vende...
# 2094  0644814                             Vendeur polyvalent H/F
# 1577  0644875                                  Coach sportif H/F
#
#                                             description        dateCreation  \
# 2003  chef bassin H/F - EC21811  p   /p \n p  strong... 2023-02-17 05:00:02
# ...

# %%
df.sort_values(by=["dateActualisation", "dateCreation"], ascending=True)
# Out:
#             id                                           intitule  \
# 61651  5035206  Ingénieur / Ingénieure d'étude informatique (H/F)
# 9257   0464844                   Ingénieur système rf (f/h) (H/F)
# 61649  8474296  EXPERT POSTGRESQL DOCKER ET INFRASTRUCTURES RA...
# 2254   8474311  ATTACHE DE RECHERCHE CLINIQUE COORDONATEUR - O...
# 9246   8474432                 CONSULTANT CYBERSÉCURITÉ GRC - H/F
# ...        ...                                                ...
# 2308   9377978  Ingénieur / Ingénieure en analyses de l'eau et...
# 2295   9638316  Ingénieur / Ingénieure en analyses de l'eau et...
# 2445   0401374  Ingénieur / Ingénieure en analyses de l'eau et...
# 2443   0401400  Ingénieur / Ingénieure en analyses de l'eau et...
# 2444   0401393  Ingénieur / Ingénieure en analyses de l'eau et...
#
#                                              description        dateCreation  \
# 61651  QUI SOMMES-NOUS ?\n    Nos équipes de l'activi... 2024-04-12 04:50:14
# ...

# %%
print(
    df.shape,
    df.columns,
)
# Out:
# (13257, 40) Index(['id', 'intitule', 'description', 'dateCreation', 'dateActualisation',
#        'lieuTravail', 'romeCode', 'romeLibelle', 'appellationlibelle',
#        'entreprise', 'typeContrat', 'typeContratLibelle', 'natureContrat',
#        'experienceExige', 'experienceLibelle', 'formations', 'langues',
#        'competences', 'salaire', 'dureeTravailLibelle',
#        'dureeTravailLibelleConverti', 'alternance', 'contact', 'agence',
#        'nombrePostes', 'accessibleTH', 'deplacementCode', 'deplacementLibelle',
#        'qualificationCode', 'qualificationLibelle', 'codeNAF',
#        'secteurActivite', 'secteurActiviteLibelle', 'qualitesProfessionnelles',
#        'origineOffre', 'offresManqueCandidats', 'permis', 'complementExercice',
#        'experienceCommentaire', 'conditionExercice'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 13257 entries, 0 to 75334
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   id                           13257 non-null  object
#  1   intitule                     13257 non-null  object
#  2   description                  13257 non-null  object
#  3   dateCreation                 13257 non-null  datetime64[ns]
#  4   dateActualisation            13257 non-null  object
#  5   lieuTravail                  13257 non-null  object
#  6   romeCode                     13257 non-null  object
#  7   romeLibelle                  13257 non-null  object
#  8   appellationlibelle           13257 non-null  object
#  9   entreprise                   13257 non-null  object
#  10  typeContrat                  13257 non-null  object
#  11  typeContratLibelle           13257 non-null  object
# ...
